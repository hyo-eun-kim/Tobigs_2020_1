# %%
# !git clone https://github.com/hyo-eun-kim/week9_CNN
# Out:
# Cloning into 'week9_CNN'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 30 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
ls
# Out:
# base/        data_loader/  model/           README.md  trainer/
# config.json  LICENSE       parse_config.py  saved/     train.py
# data/        logger/       __pycache__/     test.py    utils/

# %%
cd week9_CNN
# Out:
# [Errno 2] No such file or directory: 'week9_CNN'
# /home/heun7/week9_CNN

# %%
ls
# Out:
# base/        data_loader/  model/           README.md  trainer/
# config.json  LICENSE       parse_config.py  saved/     train.py
# data/        logger/       __pycache__/     test.py    utils/

# %%
import torch

# %%
# !python train.py --config config.json
# Out:
# Files already downloaded and verified
# ResNet32Model(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (residual_layers): Sequential(
#     (0): ResidualBlock(
#       (residual_layer): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#     (1): ResidualBlock(
#       (residual_layer): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
# !python test.py --resume ./saved/log/CIFAR10_ResNet32/0331_132239/info.log
# Out:
# Traceback (most recent call last):
#   File "test.py", line 80, in <module>
#     config = ConfigParser.from_args(args)
#   File "/home/heun7/week9_CNN/parse_config.py", line 71, in from_args
#     config = read_json(cfg_fname)
#   File "/home/heun7/week9_CNN/utils/util.py", line 15, in read_json
#     with fname.open('rt') as handle:
#   File "/opt/anaconda3/lib/python3.7/pathlib.py", line 1193, in open
#     opener=self._opener)
#   File "/opt/anaconda3/lib/python3.7/pathlib.py", line 1046, in _opener
#     return self._accessor.open(self, flags, mode)
# FileNotFoundError: [Errno 2] No such file or directory: 'saved/log/CIFAR10_ResNet32/0331_132239/config.json'

# %%
ls
# Out:
# base/        data_loader/  model/           README.md  trainer/
# config.json  LICENSE       parse_config.py  saved/     train.py
# data/        logger/       __pycache__/     test.py    utils/

# %%
# !python test.py --resume ./saved/models/CIFAR10_ResNet32/0331_132239/checkpoint-epoch10.pth
# Out:
# Files already downloaded and verified
# ResNet32Model(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (residual_layers): Sequential(
#     (0): ResidualBlock(
#       (residual_layer): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#     (1): ResidualBlock(
#       (residual_layer): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...
